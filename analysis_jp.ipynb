# %%
import pandas as pd
import numpy
import re

from jupyter_core.migrate import regex

# %%
events_df = pd.read_csv('events.csv')
users_df = pd.read_csv('users.csv')

# %%
events_df.isnull().values.any()
# Out:
# np.True_

# %%
users_df.isnull().values.any()
# Out:
# np.False_

# %%
# First checking if there are any duplicates in the user emails
duplicate_user_emails = users_df[users_df.duplicated(subset=['email']) == True ]
duplicate_user_emails
# Out:
# Empty DataFrame
# Columns: [user_id, name, email, signup_date]
# Index: []

# %%
# There are no duplicates, but if we wanted to mark them we can make a new boolean column
users_df['is_dupe'] = users_df.duplicated(subset='email', keep=False)
users_df
# Out:
#      user_id                 name                       email signup_date  \
# 0          0     Danielle Johnson  danielle.johnson@gmail.com  2024-09-27
# 1          1       Jeffery Wagner   jeffery.wagner@icloud.com  2024-07-26
# 2          2         Amy Robinson    amy.robinson@outlook.com  2023-04-12
# 3          3          Linda Wolfe       linda.wolfe@gmail.com  2025-03-07
# 4          4        Matthew Davis   matthew.davis@hotmail.com  2024-06-22
# ..       ...                  ...                         ...         ...
# 97        97  Gregory Estes White     gregory.estes@gmail.com  2024-02-19
# 98        98   Brent Wright White        brent.wright@msn.com  2024-11-13
# 99        99      Ms. Dana Cannon     dana.cannon@outlook.com  2023-10-25
# 100      100   Rick Daniels-Brown    rick.daniels@outlook.com  2024-02-09
# 101      101     Jesse Garcia III     jesse.garcia@icloud.com  2023-12-30
#
#      is_dupe
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
#
# [102 rows x 5 columns]

# %%
nulldf_events = events_df.isnull()
nulldf_events
# Out:
#      event_id  user_email  event_type  timestamp
# 0       False       False       False      False
# 1       False       False       False      False
# 2       False       False       False      False
# 3       False       False       False      False
# 4       False       False       False      False
# ..        ...         ...         ...        ...
# 495     False       False       False      False
# 496     False       False       False      False
# 497     False       False       False      False
# 498     False       False       False      False
# 499     False       False       False      False
#
# [500 rows x 4 columns]

# %%
nulldf_users = users_df.isnull()
nulldf_users
# Out:
#      user_id   name  email  signup_date  is_dupe
# 0      False  False  False        False    False
# 1      False  False  False        False    False
# 2      False  False  False        False    False
# 3      False  False  False        False    False
# 4      False  False  False        False    False
# ..       ...    ...    ...          ...      ...
# 97     False  False  False        False    False
# 98     False  False  False        False    False
# 99     False  False  False        False    False
# 100    False  False  False        False    False
# 101    False  False  False        False    False
#
# [102 rows x 5 columns]

# %%
#There are 5 event rows with NaN in the email
nanrows_events = events_df[nulldf_events.any(axis=1)]
nanrows_events
# Out:
#      event_id user_email      event_type                   timestamp
# 98         99        NaN        purchase  2023-06-16 05:11:23.034739
# 280       281        NaN        purchase  2025-02-10 15:34:22.668397
# 357       358        NaN  password_reset  2024-01-08 01:21:25.623984
# 396       397        NaN  password_reset  2024-08-22 04:55:50.082282
# 420       421        NaN           login  2023-11-10 19:33:28.225804

# %%
# There are no events with an empty string for user email
nanrows_events = events_df[events_df['user_email']=='']
nanrows_events
# Out:
# Empty DataFrame
# Columns: [event_id, user_email, event_type, timestamp]
# Index: []

# %%
#There are no users with Nan in the email
nanrows_users = users_df[nulldf_users.any(axis=1)]
nanrows_users
# Out:
# Empty DataFrame
# Columns: [user_id, name, email, signup_date, is_dupe]
# Index: []

# %%
# There are no users with an empty string for an email
nanrows_users = users_df[users_df['email']=='']
nanrows_users
# Out:
# Empty DataFrame
# Columns: [user_id, name, email, signup_date, is_dupe]
# Index: []

# %%
# Joining without normalization
# We can be sure every user entry has an email based on the above investigation
# We can use right join to ensure each event is included in the output
# Events that dont join will show up with Null values for the user columns
joined_df = users_df.merge(events_df, how="right", left_on='email', right_on='user_email')
joined_df['user_id'] = joined_df['user_id'].astype('Int64')  # capital "I" for pandas nullable integer

joined_df
# Out:
#      user_id              name                         email signup_date  \
# 0         14     Daniel Burton  daniel.burton@protonmail.com  2023-05-24
# 1       <NA>               NaN                           NaN         NaN
# 2         29     Jessica Nunez       jessica.nunez@gmail.com  2024-01-27
# 3         32       Tanya House    tanya.house@protonmail.com  2024-03-28
# 4         95    Lisa Evans-Lee            lisa.evans@msn.com  2023-07-15
# ..       ...               ...                           ...         ...
# 495       67     Justin Jordan     justin.jordan@outlook.com  2024-03-12
# 496       79        Devon Hall        devon.hall@comcast.net  2023-05-24
# 497       32       Tanya House    tanya.house@protonmail.com  2024-03-28
# 498     <NA>               NaN                           NaN         NaN
# 499       91  Jason Ryan Brown        jason.ryan@comcast.net  2023-11-21
#
#     is_dupe  event_id                    user_email       event_type  \
# 0     False         1  daniel.burton@protonmail.com           logout
# 1       NaN         2          jenniferevans@msncom         purchase
# 2     False         3       jessica.nunez@gmail.com           logout
# 3     False         4    tanya.house@protonmail.com   password_reset
# 4     False         5            lisa.evans@msn.com            login
# ..      ...       ...                           ...              ...
# 495   False       496     justin.jordan@outlook.com  updated_profile
# 496   False       497        devon.hall@comcast.net           logout
# 497   False       498    tanya.house@protonmail.com   viewed_product
# 498     NaN       499       barbarascott@outlookcom            login
# 499   False       500        jason.ryan@comcast.net  updated_profile
#
#                       timestamp
# 0    2023-09-10 20:32:58.421093
# 1    2023-12-03 23:55:36.554694
# 2    2024-10-16 07:20:12.854738
# 3    2024-01-11 04:28:54.790473
# 4    2024-10-09 13:41:53.942650
# ..                          ...
# 495  2024-01-25 01:48:58.194437
# 496  2023-08-25 21:27:20.373314
# 497  2023-07-07 11:28:07.010142
# 498  2024-12-18 17:08:01.895173
# 499  2024-03-06 09:42:34.909189
#
# [500 rows x 9 columns]

# %%
# We can take a look at the rows with null emails in the user column as well as null email in the events columns
# (Recall that we found 5 events that had NaN in the email column)

nanrows_joined = joined_df[ joined_df[['email', 'user_email']].isnull().any(axis=1) ].sort_values(by=['user_email'])
nanrows_joined
# Out:
#      user_id name email signup_date is_dupe  event_id  \
# 158     <NA>  NaN   NaN         NaN     NaN       159
# 262     <NA>  NaN   NaN         NaN     NaN       263
# 105     <NA>  NaN   NaN         NaN     NaN       106
# 20      <NA>  NaN   NaN         NaN     NaN        21
# 193     <NA>  NaN   NaN         NaN     NaN       194
# ..       ...  ...   ...         ...     ...       ...
# 98      <NA>  NaN   NaN         NaN     NaN        99
# 280     <NA>  NaN   NaN         NaN     NaN       281
# 357     <NA>  NaN   NaN         NaN     NaN       358
# 396     <NA>  NaN   NaN         NaN     NaN       397
# 420     <NA>  NaN   NaN         NaN     NaN       421
#
#                         user_email       event_type  \
# 158      amy.robinson@outlook.com   deleted_account
# 262   andrea.calderon@outlook.com            logout
# 105     barbara.scott@outlook.com   updated_profile
# 20       chelsea.jackson@live.com    password_reset
# 193      chelsea.jackson@live.com    password_reset
# ..                             ...              ...
# 98                             NaN         purchase
# 280                            NaN         purchase
# 357                            NaN   password_reset
# 396                            NaN   password_reset
# 420                            NaN            login
#
#                       timestamp
# 158  2024-04-24 23:18:50.063910
# 262  2023-08-02 22:25:58.806733
# 105  2024-02-14 01:33:05.969064
# 20   2023-07-10 10:40:06.963536
# 193  2023-05-31 09:44:45.738924
# ..                          ...
# 98   2023-06-16 05:11:23.034739
# 280  2025-02-10 15:34:22.668397
# 357  2024-01-08 01:21:25.623984
# 396  2024-08-22 04:55:50.082282
# 420  2023-11-10 19:33:28.225804
#
# [112 rows x 9 columns]

# %%
# The event_ids that did not join (without normalization)
# Ideally this number will go down post-normalization
nanrows_joined['event_id']
# Out:
# 158    159
# 262    263
# 105    106
# 20      21
# 193    194
#       ...
# 98      99
# 280    281
# 357    358
# 396    397
# 420    421
# Name: event_id, Length: 112, dtype: int64

# %%
# Out of curiosity I wanted to see if there might be a pattern in why the emails werent matched
# I used an email that I saw in the joined data set above that had an event but no user, Chelsea Jackson
# It looks like there are two password resets that didnt match, but the profile update and deleted account did
emailcheck_joined = joined_df[ joined_df['user_email'].str.contains('chelsea.jackson', na=False)  ].sort_values(by='timestamp')
emailcheck_joined
# Out:
#      user_id             name                     email signup_date is_dupe  \
# 193     <NA>              NaN                       NaN         NaN     NaN
# 20      <NA>              NaN                       NaN         NaN     NaN
# 429        8  Chelsea Jackson  chelsea.jackson@live.com  2024-01-10   False
# 143        8  Chelsea Jackson  chelsea.jackson@live.com  2024-01-10   False
#
#      event_id                  user_email       event_type  \
# 193       194   chelsea.jackson@live.com    password_reset
# 20         21   chelsea.jackson@live.com    password_reset
# 429       430    chelsea.jackson@live.com  updated_profile
# 143       144    chelsea.jackson@live.com  deleted_account
#
#                       timestamp
# 193  2023-05-31 09:44:45.738924
# 20   2023-07-10 10:40:06.963536
# 429  2023-10-13 22:53:57.236921
# 143  2024-03-23 05:08:30.684076

# %%
# The emails were identical, so I immediately suspected some kind of invisible formatting might have been causing the issue
# It looks like at least for some emails there are white spaces, and those are causing issues
# I will use repr to print out all invisible text formatting
emailcheck_joined['repr_print'] = emailcheck_joined['user_email'].map(lambda x: repr(x))
emailcheck_joined
# Out:
#      user_id             name                     email signup_date is_dupe  \
# 193     <NA>              NaN                       NaN         NaN     NaN
# 20      <NA>              NaN                       NaN         NaN     NaN
# 429        8  Chelsea Jackson  chelsea.jackson@live.com  2024-01-10   False
# 143        8  Chelsea Jackson  chelsea.jackson@live.com  2024-01-10   False
#
#      event_id                  user_email       event_type  \
# 193       194   chelsea.jackson@live.com    password_reset
# 20         21   chelsea.jackson@live.com    password_reset
# 429       430    chelsea.jackson@live.com  updated_profile
# 143       144    chelsea.jackson@live.com  deleted_account
#
#                       timestamp                    repr_print
# 193  2023-05-31 09:44:45.738924  ' chelsea.jackson@live.com '
# 20   2023-07-10 10:40:06.963536  ' chelsea.jackson@live.com '
# 429  2023-10-13 22:53:57.236921    'chelsea.jackson@live.com'
# 143  2024-03-23 05:08:30.684076    'chelsea.jackson@live.com'

# %%
# Making further use of repr(), Ive found that for many of the unmatched emails there are either trailing whitespaces or unexpected characters like
# 'elizabeth\u200b.travis@hotmail\u200b.com' or 'janet.williams\xa0@\xa0icloud.com'
# there are a few emails that don't seem to have any special characters or whitespaces- those are confirmed true negatives
nanrows_joined['repr_print'] = nanrows_joined['user_email'].map(lambda x: repr(x))
nanrows_joined.sort_values(by='user_email')
# Out:
#      user_id name email signup_date is_dupe  event_id  \
# 158     <NA>  NaN   NaN         NaN     NaN       159
# 262     <NA>  NaN   NaN         NaN     NaN       263
# 105     <NA>  NaN   NaN         NaN     NaN       106
# 20      <NA>  NaN   NaN         NaN     NaN        21
# 193     <NA>  NaN   NaN         NaN     NaN       194
# ..       ...  ...   ...         ...     ...       ...
# 98      <NA>  NaN   NaN         NaN     NaN        99
# 280     <NA>  NaN   NaN         NaN     NaN       281
# 357     <NA>  NaN   NaN         NaN     NaN       358
# 396     <NA>  NaN   NaN         NaN     NaN       397
# 420     <NA>  NaN   NaN         NaN     NaN       421
#
#                         user_email       event_type  \
# 158      amy.robinson@outlook.com   deleted_account
# 262   andrea.calderon@outlook.com            logout
# 105     barbara.scott@outlook.com   updated_profile
# 20       chelsea.jackson@live.com    password_reset
# 193      chelsea.jackson@live.com    password_reset
# ..                             ...              ...
# 98                             NaN         purchase
# 280                            NaN         purchase
# 357                            NaN   password_reset
# 396                            NaN   password_reset
# 420                            NaN            login
#
#                       timestamp                       repr_print
# 158  2024-04-24 23:18:50.063910     ' amy.robinson@outlook.com '
# 262  2023-08-02 22:25:58.806733  ' andrea.calderon@outlook.com '
# 105  2024-02-14 01:33:05.969064    ' barbara.scott@outlook.com '
# 20   2023-07-10 10:40:06.963536     ' chelsea.jackson@live.com '
# 193  2023-05-31 09:44:45.738924     ' chelsea.jackson@live.com '
# ..                          ...                              ...
# 98   2023-06-16 05:11:23.034739                              nan
# 280  2025-02-10 15:34:22.668397                              nan
# 357  2024-01-08 01:21:25.623984                              nan
# 396  2024-08-22 04:55:50.082282                              nan
# 420  2023-11-10 19:33:28.225804                              nan
#
# [112 rows x 10 columns]

# %%
# Now we can normalize the emails and see if that improves the join rate
# To normalize I will lowercase all the emails in both tables
# I will also remove any special characters/formatting/trailing spaces
# I am using the regex [^\x00-\x7F]: the range of ASCII characters is defined by \x00-\x7F and the caret ^ negates this set
# re.sub will remove anything identified above

nanrows_joined['cleaned_email'] = nanrows_joined['user_email'].astype(str).map(lambda x: re.sub(r'[^\x00-\x7F]+', '', x)).map(lambda x: x.strip()).map(lambda x: x.lower())
nanrows_joined['encoded_email_repr'] = nanrows_joined['cleaned_email'].map(lambda x: repr(x))
nanrows_joined
# Out:
#      user_id name email signup_date is_dupe  event_id  \
# 158     <NA>  NaN   NaN         NaN     NaN       159
# 262     <NA>  NaN   NaN         NaN     NaN       263
# 105     <NA>  NaN   NaN         NaN     NaN       106
# 20      <NA>  NaN   NaN         NaN     NaN        21
# 193     <NA>  NaN   NaN         NaN     NaN       194
# ..       ...  ...   ...         ...     ...       ...
# 98      <NA>  NaN   NaN         NaN     NaN        99
# 280     <NA>  NaN   NaN         NaN     NaN       281
# 357     <NA>  NaN   NaN         NaN     NaN       358
# 396     <NA>  NaN   NaN         NaN     NaN       397
# 420     <NA>  NaN   NaN         NaN     NaN       421
#
#                         user_email       event_type  \
# 158      amy.robinson@outlook.com   deleted_account
# 262   andrea.calderon@outlook.com            logout
# 105     barbara.scott@outlook.com   updated_profile
# 20       chelsea.jackson@live.com    password_reset
# 193      chelsea.jackson@live.com    password_reset
# ..                             ...              ...
# 98                             NaN         purchase
# 280                            NaN         purchase
# 357                            NaN   password_reset
# 396                            NaN   password_reset
# 420                            NaN            login
#
#                       timestamp                       repr_print  \
# 158  2024-04-24 23:18:50.063910     ' amy.robinson@outlook.com '
# 262  2023-08-02 22:25:58.806733  ' andrea.calderon@outlook.com '
# 105  2024-02-14 01:33:05.969064    ' barbara.scott@outlook.com '
# 20   2023-07-10 10:40:06.963536     ' chelsea.jackson@live.com '
# 193  2023-05-31 09:44:45.738924     ' chelsea.jackson@live.com '
# ..                          ...                              ...
# 98   2023-06-16 05:11:23.034739                              nan
# 280  2025-02-10 15:34:22.668397                              nan
# 357  2024-01-08 01:21:25.623984                              nan
# 396  2024-08-22 04:55:50.082282                              nan
# 420  2023-11-10 19:33:28.225804                              nan
#
#                    cleaned_email             encoded_email_repr
# 158     amy.robinson@outlook.com     'amy.robinson@outlook.com'
# 262  andrea.calderon@outlook.com  'andrea.calderon@outlook.com'
# 105    barbara.scott@outlook.com    'barbara.scott@outlook.com'
# 20      chelsea.jackson@live.com     'chelsea.jackson@live.com'
# 193     chelsea.jackson@live.com     'chelsea.jackson@live.com'
# ..                           ...                            ...
# 98                           nan                          'nan'
# 280                          nan                          'nan'
# 357                          nan                          'nan'
# 396                          nan                          'nan'
# 420                          nan                          'nan'
#
# [112 rows x 12 columns]

# %%
# I will apply the above to the email columns of the original dataframes
# We can then join and retry the join and check the new join rate
# I noticed that the remaining unmatched emails are missing dots in between the first and last names as well as missing dots between the domain names and .com
events_df['user_email'] =  events_df['user_email'].astype(str).map(lambda x: re.sub(r'[^\x00-\x7F]+', '', x)).map(lambda x: x.strip()).map(lambda x: x.lower())
users_df['email'] =  users_df['email'].astype(str).map(lambda x: re.sub(r'[^\x00-\x7F]+', '', x)).map(lambda x: x.strip()).map(lambda x: x.lower())

joined_df_cleaned = users_df.merge(events_df, how="right", left_on='email', right_on='user_email')

nanrows_joined_cleaned = joined_df_cleaned[ joined_df_cleaned[['email', 'user_email']].isnull().any(axis=1) ].sort_values(by=['user_email'])
nanrows_joined_cleaned
# Out:
#      user_id name email signup_date is_dupe  event_id  \
# 337      NaN  NaN   NaN         NaN     NaN       338
# 498      NaN  NaN   NaN         NaN     NaN       499
# 84       NaN  NaN   NaN         NaN     NaN        85
# 223      NaN  NaN   NaN         NaN     NaN       224
# 461      NaN  NaN   NaN         NaN     NaN       462
# 1        NaN  NaN   NaN         NaN     NaN         2
# 310      NaN  NaN   NaN         NaN     NaN       311
# 307      NaN  NaN   NaN         NaN     NaN       308
# 290      NaN  NaN   NaN         NaN     NaN       291
# 361      NaN  NaN   NaN         NaN     NaN       362
# 417      NaN  NaN   NaN         NaN     NaN       418
# 107      NaN  NaN   NaN         NaN     NaN       108
# 301      NaN  NaN   NaN         NaN     NaN       302
# 280      NaN  NaN   NaN         NaN     NaN       281
# 98       NaN  NaN   NaN         NaN     NaN        99
# 357      NaN  NaN   NaN         NaN     NaN       358
# 396      NaN  NaN   NaN         NaN     NaN       397
# 420      NaN  NaN   NaN         NaN     NaN       421
# 101      NaN  NaN   NaN         NaN     NaN       102
# 285      NaN  NaN   NaN         NaN     NaN       286
# 393      NaN  NaN   NaN         NaN     NaN       394
# 370      NaN  NaN   NaN         NaN     NaN       371
#
#                      user_email       event_type                   timestamp
# 337   andreapatterson@icloudcom            login  2023-11-26 13:22:27.872263
# 498     barbarascott@outlookcom            login  2024-12-18 17:08:01.895173
# 84          chadbeck@comcastnet         purchase  2023-12-13 20:28:49.048561
# 223      davidparker@outlookcom   password_reset  2023-08-19 19:36:13.211571
# 461           jadecarr@gmailcom            login  2023-05-25 10:06:49.957187
# 1          jenniferevans@msncom         purchase  2023-12-03 23:55:36.554694
# 310       jessicanunez@gmailcom   password_reset  2024-11-21 23:03:16.052579
# 307         johndouglas@livecom  updated_profile  2023-05-11 03:01:35.589453
# 290     josephbowers@comcastnet   password_reset  2023-11-01 20:25:13.251929
# 361       lesliewalton@yahoocom           logout  2024-11-08 03:53:38.624240
# 417        michelewalker@msncom  deleted_account  2024-06-05 14:37:58.137052
# 107        michelewalker@msncom           logout  2023-12-06 21:05:50.273419
# 301    michellecherry@icloudcom  updated_profile  2023-11-30 07:04:08.783915
# 280                         nan         purchase  2025-02-10 15:34:22.668397
# 98                          nan         purchase  2023-06-16 05:11:23.034739
# 357                         nan   password_reset  2024-01-08 01:21:25.623984
# 396                         nan   password_reset  2024-08-22 04:55:50.082282
# 420                         nan            login  2023-11-10 19:33:28.225804
# 101        nancybaker@icloudcom   viewed_product  2023-11-18 22:04:48.708847
# 285       phyllismanning@msncom         purchase  2024-11-06 07:49:56.047680
# 393      rachelclark@hotmailcom           logout  2024-08-02 01:35:32.057180
# 370  randallrocha@protonmailcom   viewed_product  2023-10-11 18:25:54.699711

# %%
# I used barbarascott@outlookcom as an example by looking up the first name
# It looks like it is available as a user, and I will assume these are just mistakes in formatting in the events

users_df[ users_df['email'].str.contains('barbara', na=False)  ]
# Out:
#     user_id           name                      email signup_date  is_dupe
# 61       61  Barbara Scott  barbara.scott@outlook.com  2025-02-12    False

# %%
# I will extract first+last names from the users table and use those to add the dots
# define a set of pre/postfixes to exclude
# im assuming the emails dont have prefixes like Mr or postfixes like Jr

# Split on space
# users_df[ users_df['name'].str.contains('Mr', na=False)  ]
users_df[['first_name', 'last_name']] = users_df['name'].str.split(' ', n=1, expand=True)
users_df['first_name']=users_df['first_name'].map(lambda x: x.strip())
users_df['last_name']=users_df['last_name'].map(lambda x: x.strip())
users_df
# Out:
#      user_id                 name                       email signup_date  \
# 0          0     Danielle Johnson  danielle.johnson@gmail.com  2024-09-27
# 1          1       Jeffery Wagner   jeffery.wagner@icloud.com  2024-07-26
# 2          2         Amy Robinson    amy.robinson@outlook.com  2023-04-12
# 3          3          Linda Wolfe       linda.wolfe@gmail.com  2025-03-07
# 4          4        Matthew Davis   matthew.davis@hotmail.com  2024-06-22
# ..       ...                  ...                         ...         ...
# 97        97  Gregory Estes White     gregory.estes@gmail.com  2024-02-19
# 98        98   Brent Wright White        brent.wright@msn.com  2024-11-13
# 99        99      Ms. Dana Cannon     dana.cannon@outlook.com  2023-10-25
# 100      100   Rick Daniels-Brown    rick.daniels@outlook.com  2024-02-09
# 101      101     Jesse Garcia III     jesse.garcia@icloud.com  2023-12-30
#
#      is_dupe first_name      last_name
# 0      False   Danielle        Johnson
# 1      False    Jeffery         Wagner
# 2      False        Amy       Robinson
# 3      False      Linda          Wolfe
# 4      False    Matthew          Davis
# ..       ...        ...            ...
# 97     False    Gregory    Estes White
# 98     False      Brent   Wright White
# 99     False        Ms.    Dana Cannon
# 100    False       Rick  Daniels-Brown
# 101    False      Jesse     Garcia III
#
# [102 rows x 7 columns]

# %%
# It looks like some names have some interesting properties
# For prefixes, we have Mrs. and Ms.
# Some people have middle names, Like Michelle Pierce White
# It looks like the emails take firstname.middlename like anna.baker@hotmail.com even though her full name is Anna Baker Lee
users_df[ users_df['last_name'].str.contains(' ', na=False)  ]
# Out:
#      user_id                   name                        email signup_date  \
# 87        87     Mrs. Erica Mcclain     erica.mcclain@icloud.com  2023-04-29
# 88        88    Andrea Calderon Lee  andrea.calderon@outlook.com  2024-06-03
# 89        89         Anna Baker Lee       anna.baker@hotmail.com  2024-01-24
# 91        91       Jason Ryan Brown       jason.ryan@comcast.net  2023-11-21
# 93        93  Michelle Pierce White   michelle.pierce@icloud.com  2024-12-09
# 94        94     Wendy Peters White         wendy.peters@msn.com  2023-11-10
# 96        96      Laura Perez White         laura.perez@live.com  2023-12-03
# 97        97    Gregory Estes White      gregory.estes@gmail.com  2024-02-19
# 98        98     Brent Wright White         brent.wright@msn.com  2024-11-13
# 99        99        Ms. Dana Cannon      dana.cannon@outlook.com  2023-10-25
# 101      101       Jesse Garcia III      jesse.garcia@icloud.com  2023-12-30
#
#      is_dupe first_name      last_name
# 87     False       Mrs.  Erica Mcclain
# 88     False     Andrea   Calderon Lee
# 89     False       Anna      Baker Lee
# 91     False      Jason     Ryan Brown
# 93     False   Michelle   Pierce White
# 94     False      Wendy   Peters White
# 96     False      Laura    Perez White
# 97     False    Gregory    Estes White
# 98     False      Brent   Wright White
# 99     False        Ms.    Dana Cannon
# 101    False      Jesse     Garcia III

# %%
# also checking for hyphens in the last name
users_df[ users_df['last_name'].str.contains('-', na=False)  ]
# Out:
#      user_id                name                     email signup_date  \
# 90        90   Mario Smith-Brown       mario.smith@aol.com  2024-12-05
# 92        92   James Davis-Smith   james.davis@outlook.com  2024-03-14
# 95        95      Lisa Evans-Lee        lisa.evans@msn.com  2023-07-15
# 100      100  Rick Daniels-Brown  rick.daniels@outlook.com  2024-02-09
#
#      is_dupe first_name      last_name
# 90     False      Mario    Smith-Brown
# 92     False      James    Davis-Smith
# 95     False       Lisa      Evans-Lee
# 100    False       Rick  Daniels-Brown

# %%
# We will remove the prefixes in a more exact manner by specifying them in a list and removing manually
# The names will be split into 3 based on ' ' and the first two will be assumed to be the email

remove_prefix_postfix = '|'.join(['Mrs.', 'Ms.', 'Mr.', 'Jr.', 'Dr.'])
users_df['name'] = users_df['name'].str.strip().replace(remove_prefix_postfix, '', regex=True).str.strip()
users_df
# Out:
#      user_id                 name                       email signup_date  \
# 0          0     Danielle Johnson  danielle.johnson@gmail.com  2024-09-27
# 1          1       Jeffery Wagner   jeffery.wagner@icloud.com  2024-07-26
# 2          2         Amy Robinson    amy.robinson@outlook.com  2023-04-12
# 3          3          Linda Wolfe       linda.wolfe@gmail.com  2025-03-07
# 4          4        Matthew Davis   matthew.davis@hotmail.com  2024-06-22
# ..       ...                  ...                         ...         ...
# 97        97  Gregory Estes White     gregory.estes@gmail.com  2024-02-19
# 98        98   Brent Wright White        brent.wright@msn.com  2024-11-13
# 99        99          Dana Cannon     dana.cannon@outlook.com  2023-10-25
# 100      100   Rick Daniels-Brown    rick.daniels@outlook.com  2024-02-09
# 101      101     Jesse Garcia III     jesse.garcia@icloud.com  2023-12-30
#
#      is_dupe first_name      last_name
# 0      False   Danielle        Johnson
# 1      False    Jeffery         Wagner
# 2      False        Amy       Robinson
# 3      False      Linda          Wolfe
# 4      False    Matthew          Davis
# ..       ...        ...            ...
# 97     False    Gregory    Estes White
# 98     False      Brent   Wright White
# 99     False        Ms.    Dana Cannon
# 100    False       Rick  Daniels-Brown
# 101    False      Jesse     Garcia III
#
# [102 rows x 7 columns]

# %%
users_df[['first_name', 'last_name', 'extra_last_name']] = users_df['name'].str.split(' ', n=3, expand=True)
users_df['first_name']=users_df['first_name'].map(lambda x: x.strip())
users_df['last_name']=users_df['last_name'].map(lambda x: x.strip())
users_df
# Out:
#      user_id                 name                       email signup_date  \
# 0          0     Danielle Johnson  danielle.johnson@gmail.com  2024-09-27
# 1          1       Jeffery Wagner   jeffery.wagner@icloud.com  2024-07-26
# 2          2         Amy Robinson    amy.robinson@outlook.com  2023-04-12
# 3          3          Linda Wolfe       linda.wolfe@gmail.com  2025-03-07
# 4          4        Matthew Davis   matthew.davis@hotmail.com  2024-06-22
# ..       ...                  ...                         ...         ...
# 97        97  Gregory Estes White     gregory.estes@gmail.com  2024-02-19
# 98        98   Brent Wright White        brent.wright@msn.com  2024-11-13
# 99        99          Dana Cannon     dana.cannon@outlook.com  2023-10-25
# 100      100   Rick Daniels-Brown    rick.daniels@outlook.com  2024-02-09
# 101      101     Jesse Garcia III     jesse.garcia@icloud.com  2023-12-30
#
#      is_dupe first_name      last_name extra_last_name
# 0      False   Danielle        Johnson            None
# 1      False    Jeffery         Wagner            None
# 2      False        Amy       Robinson            None
# 3      False      Linda          Wolfe            None
# 4      False    Matthew          Davis            None
# ..       ...        ...            ...             ...
# 97     False    Gregory          Estes           White
# 98     False      Brent         Wright           White
# 99     False       Dana         Cannon            None
# 100    False       Rick  Daniels-Brown            None
# 101    False      Jesse         Garcia             III
#
# [102 rows x 8 columns]

# %%
# Some last names are hyphenated, so I will split those out by '-' and treat the first one as the last name
# This seems to be how the emails are formatted
users_df[['last_name', 'extra_last_name']] = users_df['last_name'].str.split('-', n=3, expand=True)
users_df['first_name']=users_df['first_name'].map(lambda x: x.strip())
users_df['last_name']=users_df['last_name'].map(lambda x: x.strip())
users_df.sort_values('name')
# Out:
#     user_id                 name                        email signup_date  \
# 48       48            Adam Wise           adam.wise@live.com  2024-09-30
# 16       16         Alexander Le      alexander.le@icloud.com  2023-10-20
# 62       62          Amanda Ball        amanda.ball@yahoo.com  2023-12-30
# 2         2         Amy Robinson     amy.robinson@outlook.com  2023-04-12
# 88       88  Andrea Calderon Lee  andrea.calderon@outlook.com  2024-06-03
# ..      ...                  ...                          ...         ...
# 22       22           Todd Jones       todd.jones@outlook.com  2023-07-10
# 9         9      Veronica Bowman      veronica.bowman@msn.com  2024-12-14
# 24       24         Wanda Santos     wanda.santos@hotmail.com  2023-07-05
# 42       42          Wendy Jones      wendy.jones@hotmail.com  2025-02-18
# 94       94   Wendy Peters White         wendy.peters@msn.com  2023-11-10
#
#     is_dupe first_name last_name extra_last_name
# 48    False       Adam      Wise            None
# 16    False  Alexander        Le            None
# 62    False     Amanda      Ball            None
# 2     False        Amy  Robinson            None
# 88    False     Andrea  Calderon            None
# ..      ...        ...       ...             ...
# 22    False       Todd     Jones            None
# 9     False   Veronica    Bowman            None
# 24    False      Wanda    Santos            None
# 42    False      Wendy     Jones            None
# 94    False      Wendy    Peters            None
#
# [102 rows x 8 columns]

# %%
# concatenating the first and last names in the user table for easier comparison later
users_df['names_concat'] = users_df['first_name'].str.lower() + users_df['last_name'].str.lower()
users_df['names_concat_dot'] = users_df['first_name'].str.lower() + '.' + users_df['last_name'].str.lower()
users_df
# Out:
#      user_id                 name                       email signup_date  \
# 0          0     Danielle Johnson  danielle.johnson@gmail.com  2024-09-27
# 1          1       Jeffery Wagner   jeffery.wagner@icloud.com  2024-07-26
# 2          2         Amy Robinson    amy.robinson@outlook.com  2023-04-12
# 3          3          Linda Wolfe       linda.wolfe@gmail.com  2025-03-07
# 4          4        Matthew Davis   matthew.davis@hotmail.com  2024-06-22
# ..       ...                  ...                         ...         ...
# 97        97  Gregory Estes White     gregory.estes@gmail.com  2024-02-19
# 98        98   Brent Wright White        brent.wright@msn.com  2024-11-13
# 99        99          Dana Cannon     dana.cannon@outlook.com  2023-10-25
# 100      100   Rick Daniels-Brown    rick.daniels@outlook.com  2024-02-09
# 101      101     Jesse Garcia III     jesse.garcia@icloud.com  2023-12-30
#
#      is_dupe first_name last_name extra_last_name     names_concat  \
# 0      False   Danielle   Johnson            None  daniellejohnson
# 1      False    Jeffery    Wagner            None    jefferywagner
# 2      False        Amy  Robinson            None      amyrobinson
# 3      False      Linda     Wolfe            None       lindawolfe
# 4      False    Matthew     Davis            None     matthewdavis
# ..       ...        ...       ...             ...              ...
# 97     False    Gregory     Estes            None     gregoryestes
# 98     False      Brent    Wright            None      brentwright
# 99     False       Dana    Cannon            None       danacannon
# 100    False       Rick   Daniels           Brown      rickdaniels
# 101    False      Jesse    Garcia            None      jessegarcia
#
#      names_concat_dot
# 0    danielle.johnson
# 1      jeffery.wagner
# 2        amy.robinson
# 3         linda.wolfe
# 4       matthew.davis
# ..                ...
# 97      gregory.estes
# 98       brent.wright
# 99        dana.cannon
# 100      rick.daniels
# 101      jesse.garcia
#
# [102 rows x 10 columns]

# %%
# extracting the first/lastname portions of the email for easy comparison later
events_df['names_extract'] = events_df['user_email'].apply(lambda x: x.split('@')[0])
events_df
# Out:
#      event_id                    user_email       event_type  \
# 0           1  daniel.burton@protonmail.com           logout
# 1           2          jenniferevans@msncom         purchase
# 2           3       jessica.nunez@gmail.com           logout
# 3           4    tanya.house@protonmail.com   password_reset
# 4           5            lisa.evans@msn.com            login
# ..        ...                           ...              ...
# 495       496     justin.jordan@outlook.com  updated_profile
# 496       497        devon.hall@comcast.net           logout
# 497       498    tanya.house@protonmail.com   viewed_product
# 498       499       barbarascott@outlookcom            login
# 499       500        jason.ryan@comcast.net  updated_profile
#
#                       timestamp  names_extract
# 0    2023-09-10 20:32:58.421093  daniel.burton
# 1    2023-12-03 23:55:36.554694  jenniferevans
# 2    2024-10-16 07:20:12.854738  jessica.nunez
# 3    2024-01-11 04:28:54.790473    tanya.house
# 4    2024-10-09 13:41:53.942650     lisa.evans
# ..                          ...            ...
# 495  2024-01-25 01:48:58.194437  justin.jordan
# 496  2023-08-25 21:27:20.373314     devon.hall
# 497  2023-07-07 11:28:07.010142    tanya.house
# 498  2024-12-18 17:08:01.895173   barbarascott
# 499  2024-03-06 09:42:34.909189     jason.ryan
#
# [500 rows x 5 columns]

# %%
# now we have extracted the first and last names we need to fix some of the missing emails from before
# In the joined dataframe, we can look at events that havent matched (null user info)
# for each event, check the users table to see if the person's name exists
# if the name exists then replace the part of the email before the @ with first_name.last_name
# replace com or net with .com or .net

joined_df_cleaned_names_separated = users_df.merge(events_df, how="right", left_on='email', right_on='user_email')

nanrows_joined_cleaned_names_separated = joined_df_cleaned_names_separated[ joined_df_cleaned_names_separated[['email']].isnull().any(axis=1) ].sort_values(by=['user_email'])
nanrows_joined_cleaned_names_separated
# Out:
#      user_id name email signup_date is_dupe first_name last_name  \
# 337      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 498      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 84       NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 223      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 461      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 1        NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 310      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 307      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 290      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 361      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 417      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 107      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 301      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 280      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 98       NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 357      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 396      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 420      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 101      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 285      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 393      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 370      NaN  NaN   NaN         NaN     NaN        NaN       NaN
#
#     extra_last_name names_concat names_concat_dot  event_id  \
# 337             NaN          NaN              NaN       338
# 498             NaN          NaN              NaN       499
# 84              NaN          NaN              NaN        85
# 223             NaN          NaN              NaN       224
# 461             NaN          NaN              NaN       462
# 1               NaN          NaN              NaN         2
# 310             NaN          NaN              NaN       311
# 307             NaN          NaN              NaN       308
# 290             NaN          NaN              NaN       291
# 361             NaN          NaN              NaN       362
# 417             NaN          NaN              NaN       418
# 107             NaN          NaN              NaN       108
# 301             NaN          NaN              NaN       302
# 280             NaN          NaN              NaN       281
# 98              NaN          NaN              NaN        99
# 357             NaN          NaN              NaN       358
# 396             NaN          NaN              NaN       397
# 420             NaN          NaN              NaN       421
# 101             NaN          NaN              NaN       102
# 285             NaN          NaN              NaN       286
# 393             NaN          NaN              NaN       394
# 370             NaN          NaN              NaN       371
#
#                      user_email       event_type                   timestamp  \
# 337   andreapatterson@icloudcom            login  2023-11-26 13:22:27.872263
# 498     barbarascott@outlookcom            login  2024-12-18 17:08:01.895173
# 84          chadbeck@comcastnet         purchase  2023-12-13 20:28:49.048561
# 223      davidparker@outlookcom   password_reset  2023-08-19 19:36:13.211571
# 461           jadecarr@gmailcom            login  2023-05-25 10:06:49.957187
# 1          jenniferevans@msncom         purchase  2023-12-03 23:55:36.554694
# 310       jessicanunez@gmailcom   password_reset  2024-11-21 23:03:16.052579
# 307         johndouglas@livecom  updated_profile  2023-05-11 03:01:35.589453
# 290     josephbowers@comcastnet   password_reset  2023-11-01 20:25:13.251929
# 361       lesliewalton@yahoocom           logout  2024-11-08 03:53:38.624240
# 417        michelewalker@msncom  deleted_account  2024-06-05 14:37:58.137052
# 107        michelewalker@msncom           logout  2023-12-06 21:05:50.273419
# 301    michellecherry@icloudcom  updated_profile  2023-11-30 07:04:08.783915
# 280                         nan         purchase  2025-02-10 15:34:22.668397
# 98                          nan         purchase  2023-06-16 05:11:23.034739
# 357                         nan   password_reset  2024-01-08 01:21:25.623984
# 396                         nan   password_reset  2024-08-22 04:55:50.082282
# 420                         nan            login  2023-11-10 19:33:28.225804
# 101        nancybaker@icloudcom   viewed_product  2023-11-18 22:04:48.708847
# 285       phyllismanning@msncom         purchase  2024-11-06 07:49:56.047680
# 393      rachelclark@hotmailcom           logout  2024-08-02 01:35:32.057180
# 370  randallrocha@protonmailcom   viewed_product  2023-10-11 18:25:54.699711
#
#        names_extract
# 337  andreapatterson
# 498     barbarascott
# 84          chadbeck
# 223      davidparker
# 461         jadecarr
# 1      jenniferevans
# 310     jessicanunez
# 307      johndouglas
# 290     josephbowers
# 361     lesliewalton
# 417    michelewalker
# 107    michelewalker
# 301   michellecherry
# 280              nan
# 98               nan
# 357              nan
# 396              nan
# 420              nan
# 101       nancybaker
# 285   phyllismanning
# 393      rachelclark
# 370     randallrocha

# %%
# We want to check only the events where email in the user table is null
# where its null, mark the new column matched_name as true
# we will use this column later to single out those incorrect emails and fix them, the assumption being that some formatting mistake happened
# they also happen to be the ones with incorrect domains so we can fix those as well

mask = joined_df_cleaned_names_separated['email'].isnull()
joined_df_cleaned_names_separated.loc[mask, 'matched_name'] = joined_df_cleaned_names_separated.loc[mask, 'names_extract'].apply(
    lambda x: any(name in str(x).lower() for name in users_df['names_concat'].str.lower())
)
joined_df_cleaned_names_separated[ joined_df_cleaned_names_separated['matched_name'] == True]
# Out:
#      user_id name email signup_date is_dupe first_name last_name  \
# 1        NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 84       NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 101      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 107      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 223      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 285      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 290      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 301      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 307      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 310      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 337      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 361      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 370      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 393      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 417      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 461      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 498      NaN  NaN   NaN         NaN     NaN        NaN       NaN
#
#     extra_last_name names_concat names_concat_dot  event_id  \
# 1               NaN          NaN              NaN         2
# 84              NaN          NaN              NaN        85
# 101             NaN          NaN              NaN       102
# 107             NaN          NaN              NaN       108
# 223             NaN          NaN              NaN       224
# 285             NaN          NaN              NaN       286
# 290             NaN          NaN              NaN       291
# 301             NaN          NaN              NaN       302
# 307             NaN          NaN              NaN       308
# 310             NaN          NaN              NaN       311
# 337             NaN          NaN              NaN       338
# 361             NaN          NaN              NaN       362
# 370             NaN          NaN              NaN       371
# 393             NaN          NaN              NaN       394
# 417             NaN          NaN              NaN       418
# 461             NaN          NaN              NaN       462
# 498             NaN          NaN              NaN       499
#
#                      user_email       event_type                   timestamp  \
# 1          jenniferevans@msncom         purchase  2023-12-03 23:55:36.554694
# 84          chadbeck@comcastnet         purchase  2023-12-13 20:28:49.048561
# 101        nancybaker@icloudcom   viewed_product  2023-11-18 22:04:48.708847
# 107        michelewalker@msncom           logout  2023-12-06 21:05:50.273419
# 223      davidparker@outlookcom   password_reset  2023-08-19 19:36:13.211571
# 285       phyllismanning@msncom         purchase  2024-11-06 07:49:56.047680
# 290     josephbowers@comcastnet   password_reset  2023-11-01 20:25:13.251929
# 301    michellecherry@icloudcom  updated_profile  2023-11-30 07:04:08.783915
# 307         johndouglas@livecom  updated_profile  2023-05-11 03:01:35.589453
# 310       jessicanunez@gmailcom   password_reset  2024-11-21 23:03:16.052579
# 337   andreapatterson@icloudcom            login  2023-11-26 13:22:27.872263
# 361       lesliewalton@yahoocom           logout  2024-11-08 03:53:38.624240
# 370  randallrocha@protonmailcom   viewed_product  2023-10-11 18:25:54.699711
# 393      rachelclark@hotmailcom           logout  2024-08-02 01:35:32.057180
# 417        michelewalker@msncom  deleted_account  2024-06-05 14:37:58.137052
# 461           jadecarr@gmailcom            login  2023-05-25 10:06:49.957187
# 498     barbarascott@outlookcom            login  2024-12-18 17:08:01.895173
#
#        names_extract matched_name
# 1      jenniferevans         True
# 84          chadbeck         True
# 101       nancybaker         True
# 107    michelewalker         True
# 223      davidparker         True
# 285   phyllismanning         True
# 290     josephbowers         True
# 301   michellecherry         True
# 307      johndouglas         True
# 310     jessicanunez         True
# 337  andreapatterson         True
# 361     lesliewalton         True
# 370     randallrocha         True
# 393      rachelclark         True
# 417    michelewalker         True
# 461         jadecarr         True
# 498     barbarascott         True

# %%
emails_to_fix = joined_df_cleaned_names_separated[ joined_df_cleaned_names_separated['matched_name'] == True]
emails_to_fix.sort_values(by='user_email')
# Out:
#      user_id name email signup_date is_dupe first_name last_name  \
# 337      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 498      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 84       NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 223      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 461      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 1        NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 310      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 307      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 290      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 361      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 107      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 417      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 301      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 101      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 285      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 393      NaN  NaN   NaN         NaN     NaN        NaN       NaN
# 370      NaN  NaN   NaN         NaN     NaN        NaN       NaN
#
#     extra_last_name names_concat names_concat_dot  event_id  \
# 337             NaN          NaN              NaN       338
# 498             NaN          NaN              NaN       499
# 84              NaN          NaN              NaN        85
# 223             NaN          NaN              NaN       224
# 461             NaN          NaN              NaN       462
# 1               NaN          NaN              NaN         2
# 310             NaN          NaN              NaN       311
# 307             NaN          NaN              NaN       308
# 290             NaN          NaN              NaN       291
# 361             NaN          NaN              NaN       362
# 107             NaN          NaN              NaN       108
# 417             NaN          NaN              NaN       418
# 301             NaN          NaN              NaN       302
# 101             NaN          NaN              NaN       102
# 285             NaN          NaN              NaN       286
# 393             NaN          NaN              NaN       394
# 370             NaN          NaN              NaN       371
#
#                      user_email       event_type                   timestamp  \
# 337   andreapatterson@icloudcom            login  2023-11-26 13:22:27.872263
# 498     barbarascott@outlookcom            login  2024-12-18 17:08:01.895173
# 84          chadbeck@comcastnet         purchase  2023-12-13 20:28:49.048561
# 223      davidparker@outlookcom   password_reset  2023-08-19 19:36:13.211571
# 461           jadecarr@gmailcom            login  2023-05-25 10:06:49.957187
# 1          jenniferevans@msncom         purchase  2023-12-03 23:55:36.554694
# 310       jessicanunez@gmailcom   password_reset  2024-11-21 23:03:16.052579
# 307         johndouglas@livecom  updated_profile  2023-05-11 03:01:35.589453
# 290     josephbowers@comcastnet   password_reset  2023-11-01 20:25:13.251929
# 361       lesliewalton@yahoocom           logout  2024-11-08 03:53:38.624240
# 107        michelewalker@msncom           logout  2023-12-06 21:05:50.273419
# 417        michelewalker@msncom  deleted_account  2024-06-05 14:37:58.137052
# 301    michellecherry@icloudcom  updated_profile  2023-11-30 07:04:08.783915
# 101        nancybaker@icloudcom   viewed_product  2023-11-18 22:04:48.708847
# 285       phyllismanning@msncom         purchase  2024-11-06 07:49:56.047680
# 393      rachelclark@hotmailcom           logout  2024-08-02 01:35:32.057180
# 370  randallrocha@protonmailcom   viewed_product  2023-10-11 18:25:54.699711
#
#        names_extract matched_name
# 337  andreapatterson         True
# 498     barbarascott         True
# 84          chadbeck         True
# 223      davidparker         True
# 461         jadecarr         True
# 1      jenniferevans         True
# 310     jessicanunez         True
# 307      johndouglas         True
# 290     josephbowers         True
# 361     lesliewalton         True
# 107    michelewalker         True
# 417    michelewalker         True
# 301   michellecherry         True
# 101       nancybaker         True
# 285   phyllismanning         True
# 393      rachelclark         True
# 370     randallrocha         True

# %%
# use the above list to identify emails in the events table that are not formed properly
# use that list to derive a lookup table from the users table using the concatenated names
# fix them in-place in the events table as described above using this lookup table

users_with_broken_emails_in_events = users_df[ users_df['names_concat'].isin(emails_to_fix['names_extract']) ]
users_with_broken_emails_in_events.sort_values(by='email')
# Out:
#     user_id              name                         email signup_date  \
# 49       49  Andrea Patterson   andrea.patterson@icloud.com  2025-01-12
# 61       61     Barbara Scott     barbara.scott@outlook.com  2025-02-12
# 63       63         Chad Beck         chad.beck@comcast.net  2024-12-17
# 51       51      David Parker      david.parker@outlook.com  2024-12-27
# 44       44         Jade Carr           jade.carr@gmail.com  2023-04-13
# 64       64    Jennifer Evans        jennifer.evans@msn.com  2024-01-27
# 29       29     Jessica Nunez       jessica.nunez@gmail.com  2024-01-27
# 73       73      John Douglas         john.douglas@live.com  2024-10-21
# 34       34     Joseph Bowers     joseph.bowers@comcast.net  2025-03-07
# 41       41     Leslie Walton       leslie.walton@yahoo.com  2025-04-06
# 57       57    Michele Walker        michele.walker@msn.com  2023-11-17
# 54       54   Michelle Cherry    michelle.cherry@icloud.com  2023-04-26
# 18       18       Nancy Baker        nancy.baker@icloud.com  2025-02-03
# 77       77   Phyllis Manning       phyllis.manning@msn.com  2023-10-05
# 52       52      Rachel Clark      rachel.clark@hotmail.com  2024-10-29
# 12       12     Randall Rocha  randall.rocha@protonmail.com  2023-10-05
#
#     is_dupe first_name  last_name extra_last_name     names_concat  \
# 49    False     Andrea  Patterson            None  andreapatterson
# 61    False    Barbara      Scott            None     barbarascott
# 63    False       Chad       Beck            None         chadbeck
# 51    False      David     Parker            None      davidparker
# 44    False       Jade       Carr            None         jadecarr
# 64    False   Jennifer      Evans            None    jenniferevans
# 29    False    Jessica      Nunez            None     jessicanunez
# 73    False       John    Douglas            None      johndouglas
# 34    False     Joseph     Bowers            None     josephbowers
# 41    False     Leslie     Walton            None     lesliewalton
# 57    False    Michele     Walker            None    michelewalker
# 54    False   Michelle     Cherry            None   michellecherry
# 18    False      Nancy      Baker            None       nancybaker
# 77    False    Phyllis    Manning            None   phyllismanning
# 52    False     Rachel      Clark            None      rachelclark
# 12    False    Randall      Rocha            None     randallrocha
#
#     names_concat_dot
# 49  andrea.patterson
# 61     barbara.scott
# 63         chad.beck
# 51      david.parker
# 44         jade.carr
# 64    jennifer.evans
# 29     jessica.nunez
# 73      john.douglas
# 34     joseph.bowers
# 41     leslie.walton
# 57    michele.walker
# 54   michelle.cherry
# 18       nancy.baker
# 77   phyllis.manning
# 52      rachel.clark
# 12     randall.rocha

# %%
#First clean up the domains
# if there are more domains we can make a more complex function later to handle that replacement

mask = events_df['names_extract'].isin(users_with_broken_emails_in_events['names_concat'])

events_df.loc[mask, 'user_email'] = events_df.loc[mask, 'user_email'].str.replace(r'com$', '.com', regex=True)
events_df.loc[mask, 'user_email'] = events_df.loc[mask, 'user_email'].str.replace(r'net$', '.net', regex=True)
events_df[mask]
# Out:
#      event_id                   user_email       event_type  \
# 1           2        jenniferevans@msn.com         purchase
# 84         85         chadbeck@comcast.net         purchase
# 101       102        nancybaker@icloud.com   viewed_product
# 107       108        michelewalker@msn.com           logout
# 223       224      davidparker@outlook.com   password_reset
# 285       286       phyllismanning@msn.com         purchase
# 290       291     josephbowers@comcast.net   password_reset
# 301       302    michellecherry@icloud.com  updated_profile
# 307       308         johndouglas@live.com  updated_profile
# 310       311       jessicanunez@gmail.com   password_reset
# 337       338   andreapatterson@icloud.com            login
# 361       362       lesliewalton@yahoo.com           logout
# 370       371  randallrocha@protonmail.com   viewed_product
# 393       394      rachelclark@hotmail.com           logout
# 417       418        michelewalker@msn.com  deleted_account
# 461       462           jadecarr@gmail.com            login
# 498       499     barbarascott@outlook.com            login
#
#                       timestamp    names_extract
# 1    2023-12-03 23:55:36.554694    jenniferevans
# 84   2023-12-13 20:28:49.048561         chadbeck
# 101  2023-11-18 22:04:48.708847       nancybaker
# 107  2023-12-06 21:05:50.273419    michelewalker
# 223  2023-08-19 19:36:13.211571      davidparker
# 285  2024-11-06 07:49:56.047680   phyllismanning
# 290  2023-11-01 20:25:13.251929     josephbowers
# 301  2023-11-30 07:04:08.783915   michellecherry
# 307  2023-05-11 03:01:35.589453      johndouglas
# 310  2024-11-21 23:03:16.052579     jessicanunez
# 337  2023-11-26 13:22:27.872263  andreapatterson
# 361  2024-11-08 03:53:38.624240     lesliewalton
# 370  2023-10-11 18:25:54.699711     randallrocha
# 393  2024-08-02 01:35:32.057180      rachelclark
# 417  2024-06-05 14:37:58.137052    michelewalker
# 461  2023-05-25 10:06:49.957187         jadecarr
# 498  2024-12-18 17:08:01.895173     barbarascott

# %%
# split out the email to before the @ and after the @ to isolate the now fixed domains
# make a new column with the names_concat_dot information from users
# replace the user_email for the malformed emails with a concatenation between the two

events_df.loc[mask, 'user_email_split'] = events_df.loc[mask,'user_email'].apply(lambda x: x.split('@')[1])

events_df = events_df.merge(
    users_df[['names_concat', 'names_concat_dot']],
    left_on='names_extract',
    right_on='names_concat',
    how='left'
)

events_df.drop(columns=['names_concat'], inplace=True)

events_df.loc[mask, 'user_email'] = events_df.loc[mask,'names_concat_dot'] + '@' + events_df.loc[mask,'user_email_split']

events_df[mask]
# Out:
#      event_id                    user_email       event_type  \
# 1           2        jennifer.evans@msn.com         purchase
# 84         85         chad.beck@comcast.net         purchase
# 101       102        nancy.baker@icloud.com   viewed_product
# 107       108        michele.walker@msn.com           logout
# 223       224      david.parker@outlook.com   password_reset
# 285       286       phyllis.manning@msn.com         purchase
# 290       291     joseph.bowers@comcast.net   password_reset
# 301       302    michelle.cherry@icloud.com  updated_profile
# 307       308         john.douglas@live.com  updated_profile
# 310       311       jessica.nunez@gmail.com   password_reset
# 337       338   andrea.patterson@icloud.com            login
# 361       362       leslie.walton@yahoo.com           logout
# 370       371  randall.rocha@protonmail.com   viewed_product
# 393       394      rachel.clark@hotmail.com           logout
# 417       418        michele.walker@msn.com  deleted_account
# 461       462           jade.carr@gmail.com            login
# 498       499     barbara.scott@outlook.com            login
#
#                       timestamp    names_extract user_email_split  \
# 1    2023-12-03 23:55:36.554694    jenniferevans          msn.com
# 84   2023-12-13 20:28:49.048561         chadbeck      comcast.net
# 101  2023-11-18 22:04:48.708847       nancybaker       icloud.com
# 107  2023-12-06 21:05:50.273419    michelewalker          msn.com
# 223  2023-08-19 19:36:13.211571      davidparker      outlook.com
# 285  2024-11-06 07:49:56.047680   phyllismanning          msn.com
# 290  2023-11-01 20:25:13.251929     josephbowers      comcast.net
# 301  2023-11-30 07:04:08.783915   michellecherry       icloud.com
# 307  2023-05-11 03:01:35.589453      johndouglas         live.com
# 310  2024-11-21 23:03:16.052579     jessicanunez        gmail.com
# 337  2023-11-26 13:22:27.872263  andreapatterson       icloud.com
# 361  2024-11-08 03:53:38.624240     lesliewalton        yahoo.com
# 370  2023-10-11 18:25:54.699711     randallrocha   protonmail.com
# 393  2024-08-02 01:35:32.057180      rachelclark      hotmail.com
# 417  2024-06-05 14:37:58.137052    michelewalker          msn.com
# 461  2023-05-25 10:06:49.957187         jadecarr        gmail.com
# 498  2024-12-18 17:08:01.895173     barbarascott      outlook.com
#
#      names_concat_dot
# 1      jennifer.evans
# 84          chad.beck
# 101       nancy.baker
# 107    michele.walker
# 223      david.parker
# 285   phyllis.manning
# 290     joseph.bowers
# 301   michelle.cherry
# 307      john.douglas
# 310     jessica.nunez
# 337  andrea.patterson
# 361     leslie.walton
# 370     randall.rocha
# 393      rachel.clark
# 417    michele.walker
# 461         jade.carr
# 498     barbara.scott

# %%
events_df
# Out:
#      event_id                    user_email       event_type  \
# 0           1  daniel.burton@protonmail.com           logout
# 1           2        jennifer.evans@msn.com         purchase
# 2           3       jessica.nunez@gmail.com           logout
# 3           4    tanya.house@protonmail.com   password_reset
# 4           5            lisa.evans@msn.com            login
# ..        ...                           ...              ...
# 495       496     justin.jordan@outlook.com  updated_profile
# 496       497        devon.hall@comcast.net           logout
# 497       498    tanya.house@protonmail.com   viewed_product
# 498       499     barbara.scott@outlook.com            login
# 499       500        jason.ryan@comcast.net  updated_profile
#
#                       timestamp  names_extract user_email_split  \
# 0    2023-09-10 20:32:58.421093  daniel.burton              NaN
# 1    2023-12-03 23:55:36.554694  jenniferevans          msn.com
# 2    2024-10-16 07:20:12.854738  jessica.nunez              NaN
# 3    2024-01-11 04:28:54.790473    tanya.house              NaN
# 4    2024-10-09 13:41:53.942650     lisa.evans              NaN
# ..                          ...            ...              ...
# 495  2024-01-25 01:48:58.194437  justin.jordan              NaN
# 496  2023-08-25 21:27:20.373314     devon.hall              NaN
# 497  2023-07-07 11:28:07.010142    tanya.house              NaN
# 498  2024-12-18 17:08:01.895173   barbarascott      outlook.com
# 499  2024-03-06 09:42:34.909189     jason.ryan              NaN
#
#     names_concat_dot
# 0                NaN
# 1     jennifer.evans
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 495              NaN
# 496              NaN
# 497              NaN
# 498    barbara.scott
# 499              NaN
#
# [500 rows x 7 columns]

# %%
print(users_df.head())
# Out:
#    user_id              name                       email signup_date  is_dupe  \
# 0        0  Danielle Johnson  danielle.johnson@gmail.com  2024-09-27    False
# 1        1    Jeffery Wagner   jeffery.wagner@icloud.com  2024-07-26    False
# 2        2      Amy Robinson    amy.robinson@outlook.com  2023-04-12    False
# 3        3       Linda Wolfe       linda.wolfe@gmail.com  2025-03-07    False
# 4        4     Matthew Davis   matthew.davis@hotmail.com  2024-06-22    False
#
#   first_name last_name extra_last_name     names_concat  names_concat_dot
# 0   Danielle   Johnson            None  daniellejohnson  danielle.johnson
# 1    Jeffery    Wagner            None    jefferywagner    jeffery.wagner
# 2        Amy  Robinson            None      amyrobinson      amy.robinson
# 3      Linda     Wolfe            None       lindawolfe       linda.wolfe
# 4    Matthew     Davis            None     matthewdavis     matthew.davis

# %%
# Now we should have a very clean event data set
# We can join once more and check out the merge rate
# The onl events that did not match are the five with no user emails in the events table
# Our cleanup efforts paid off
joined_df_cleaned_final = users_df.merge(events_df, how="right", left_on='email', right_on='user_email')

nanrows_joined_cleaned_final = joined_df_cleaned_final[ joined_df_cleaned_final[['email']].isnull().any(axis=1) ].sort_values(by=['user_email'])
nanrows_joined_cleaned_final['event_id']
# Out:
# 98      99
# 280    281
# 357    358
# 396    397
# 420    421
# Name: event_id, dtype: int64

# %%
joined_df_cleaned_final['user_id'] = joined_df_cleaned_final['user_id'].astype('Int64')  # capital "I" for pandas nullable integer

joined_df_cleaned_final = joined_df_cleaned_final[['user_id', 'first_name', 'last_name', 'event_type', 'timestamp', 'signup_date']]

# %%
joined_df_cleaned_final.to_csv('joined_events.csv', index=False)
